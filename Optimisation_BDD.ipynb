# %%
from IPython.display import display, HTML 
import numpy as np
import pandas as pd
import pymysql
import sqlalchemy as db

# %%
data = pd.read_csv('data_Us.csv')
data.head(3)
# Out:
#    Unnamed: 0   ID    Source    TMC  Severity           Start_Time  \
# 0           0  A-1  MapQuest  201.0         3  2016-02-08 05:46:00
# 1           1  A-2  MapQuest  201.0         2  2016-02-08 06:07:59
# 2           2  A-3  MapQuest  201.0         2  2016-02-08 06:49:27
#
#               End_Time  Start_Lat  Start_Lng  Distance  ... Roundabout  \
# 0  2016-02-08 11:00:00  39.865147 -84.058723      0.01  ...      False
# 1  2016-02-08 06:37:59  39.928059 -82.831184      0.01  ...      False
# 2  2016-02-08 07:19:27  39.063148 -84.032608      0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0   False  False           False          False        False          Night
# 1   False  False           False          False        False          Night
# 2   False  False           False           True        False          Night
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# ...

# %%
def max_length(df):
    df_col_name = []  
    df_col_dtype = []  
    df_max_length = []  
    df_min_length = []
    df_header = ["Col Name", "Col Type", "Min" ,"Max"]
    for col in df.columns:
        df_col_name.append(col) 
        if df[col].dtypes =='object':
            df_col_dtype.append('Object_Type')
            max = df[col].apply(lambda x :len(x)).max()
            df_max_length.append(max)
            min = df[col].apply(lambda x :len(x)).min()
            df_min_length.append(min)
        elif df[col].dtypes=='int64':
            df_col_dtype.append('Entier')
            max = df[col].max()
            df_max_length.append(max)
            min = df[col].min()
            df_min_length.append(min)
        elif df[col].dtypes=='float64':
            df_col_dtype.append('Float')
            max = df[col].max()
            df_max_length.append(max)
            min = df[col].min()
            df_min_length.append(min)
        elif data[col].dtypes.kind == 'M':
            df_col_dtype.append('date/time (oldest most recent)') # Store the data type for the current col.
            max = data[col].max()  # Get the max  max number of current col (NaN removed).
            df_max_length.append(max)
            min = data[col].min()  # Get the max  max number of current col (NaN removed).
            df_min_length.append(min)
        elif data[col].dtypes =='bool':
            df_col_dtype.append('Boolean')
            max = data[col].max()  # Get the max  max number of current col (NaN removed).
            df_max_length.append(max)
            min = data[col].min()  # Get the max  max number of current col (NaN removed).
            df_min_length.append(min)
    result = list(zip(df_col_name, df_col_dtype, df_min_length, df_max_length)) # Merges the lists containing col names & max values.
    df_result = pd.DataFrame(result, columns = df_header)
    return df_result

# %%
max_length(data)
# Out:
#                  Col Name     Col Type      Min      Max
# 0              Unnamed: 0       Entier        0  2974334
# 1                      ID  Object_Type        3        9
# 2                  Source  Object_Type        4       13
# 3                     TMC        Float      200      406
# 4                Severity       Entier        1        4
# 5              Start_Time  Object_Type       19       19
# 6                End_Time  Object_Type       19       19
# 7               Start_Lat        Float  24.5553  49.0022
# 8               Start_Lng        Float -124.624 -67.1132
# 9                Distance        Float        0   333.63
# 10            Description  Object_Type       14      440
# 11                 Street  Object_Type        1       59
# 12                   Side  Object_Type        1        1
# 13                   City  Object_Type        3       30
# 14                 County  Object_Type        3       21
# ...
